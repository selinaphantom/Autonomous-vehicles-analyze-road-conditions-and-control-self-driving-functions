# %%
from google.colab import drive
drive.mount('/content/drive')
# !ln -s /content/drive/My\ Drive/ /mydrive
# !ls /mydrive

# %%
# !ls
# Out:
# 3rdparty		 DarknetConfig.cmake.in  image_yolov4.sh	results
# backup			 darknet_images.py	 include		scripts
# build			 darknet.py		 json_mjpeg_streams.sh	src
# build.ps1		 darknet_video.py	 LICENSE		vcpkg.json
# cfg			 data			 Makefile		vcpkg.json.opencv23
# chart.png		 demo2.mp4		 net_cam_v3.sh		video_yolov3.sh
# chart_yolov4-custom.png  docker-compose.yml	 net_cam_v4.sh		video_yolov4.sh
# cmake			 Dockerfile.cpu		 obj			yolov3.weights
# CMakeLists.txt		 Dockerfile.gpu		 package.xml		yolov4.conv.137
# darknet			 generate_train.py	 predictions.jpg	yolov4.weights
# darknet53.conv.74	 image_yolov3.sh	 README.md

# %%
#!mkdir /mydrive/project2_2023
# %cd /mydrive/project2_class2/
# !ls
# Out:
# /content/drive/My Drive/project2_class2
# darknet    generate_train.py  obj.names  yolov4-custom.cfg
# demo2.mp4  obj.data	      obj.zip	 yolov4-custom_last.weights

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15851 (delta 5), reused 13 (delta 4), pack-reused 15833
# Receiving objects: 100% (15851/15851), 14.42 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (10671/10671), done.
# Updating files: 100% (2056/2056), done.

# %%
# %cd darknet
# !sed -i "s/GPU=0/GPU=1/" Makefile
# !sed -i "s/OPENCV=0/OPENCV=1/" Makefile
# !sed -i "s/CUDNN=0/CUDNN=1/" Makefile
# !sed -i "s/CUDNN_HALF=0/CUDNN_HALF=1/" Makefile
# Out:
# /content/drive/MyDrive/project2_class2/darknet

# %%
# !ls
# %cd /content/drive/MyDrive/project2_class2/darknet
# Out:
# 3rdparty	DarknetConfig.cmake.in	Dockerfile.cpu	       LICENSE	      scripts
# build		darknet_images.py	Dockerfile.gpu	       Makefile       src
# build.ps1	darknet.py		image_yolov3.sh        net_cam_v3.sh  vcpkg.json
# cfg		darknet_video.py	image_yolov4.sh        net_cam_v4.sh  vcpkg.json.opencv23
# cmake		data			include		       package.xml    video_yolov3.sh
# CMakeLists.txt	docker-compose.yml	json_mjpeg_streams.sh  README.md      video_yolov4.sh
# /content/drive/MyDrive/project2_class2/darknet

# %%
# %cd darknet
# !ls
# Out:
# /content/drive/My Drive/project2_class2/darknet
# 3rdparty		 DarknetConfig.cmake.in  image_yolov4.sh	results
# backup			 darknet_images.py	 include		scripts
# build			 darknet.py		 json_mjpeg_streams.sh	src
# build.ps1		 darknet_video.py	 LICENSE		vcpkg.json
# cfg			 data			 Makefile		vcpkg.json.opencv23
# chart.png		 demo2.mp4		 net_cam_v3.sh		video_yolov3.sh
# chart_yolov4-custom.png  docker-compose.yml	 net_cam_v4.sh		video_yolov4.sh
# cmake			 Dockerfile.cpu		 obj			yolov3.weights
# CMakeLists.txt		 Dockerfile.gpu		 package.xml		yolov4.conv.137
# darknet			 generate_train.py	 predictions.jpg	yolov4.weights
# darknet53.conv.74	 image_yolov3.sh	 README.md

# %%
# !ls
# !unzip ../obj.zip -d data/obj
# !cp ../yolov4-custom.cfg ./cfg
# !cp ../obj.data ./data
# !cp ../obj.names ./data
# !cp ../generate_train.py ./
# Out:
# 3rdparty	darknet53.conv.74	Dockerfile.gpu	       net_cam_v3.sh	src
# backup		DarknetConfig.cmake.in	generate_train.py      net_cam_v4.sh	vcpkg.json
# build		darknet_images.py	image_yolov3.sh        obj		vcpkg.json.opencv23
# build.ps1	darknet.py		image_yolov4.sh        package.xml	video_yolov3.sh
# cfg		darknet_video.py	include		       predictions.jpg	video_yolov4.sh
# cmake		data			json_mjpeg_streams.sh  README.md	yolov3.weights
# CMakeLists.txt	docker-compose.yml	LICENSE		       results		yolov4.conv.137
# darknet		Dockerfile.cpu		Makefile	       scripts		yolov4.weights
# Archive:  ../obj.zip
#   inflating: data/obj/obj/1_png.rf.7cf612fa674327e81ca105f53d34c13a.jpg
#   inflating: data/obj/obj/1_png.rf.7cf612fa674327e81ca105f53d34c13a.txt
#   inflating: data/obj/obj/1_png.rf.e6470864bb844219fa7bf074eaa456ae.jpg
#   inflating: data/obj/obj/1_png.rf.e6470864bb844219fa7bf074eaa456ae.txt
#   inflating: data/obj/obj/10_png.rf.ee9a94ecfe872b626e275c0be1920edd.jpg
# ...

# %%
# !python generate_train.py
# Out:
# start
# 1_png.rf.7cf612fa674327e81ca105f53d34c13a.jpg
# 1_png.rf.e6470864bb844219fa7bf074eaa456ae.jpg
# 10_png.rf.ee9a94ecfe872b626e275c0be1920edd.jpg
# 11_png.rf.b35dcea4249c9aedb95d1ece8c25ca77.jpg
# 12_png.rf.51e31321591c531f07953b48f5ca5ce0.jpg
# 12_png.rf.ad9605e848daa47e4fc4a57038522f4c.jpg
# 12_png.rf.bb36e3713d9935a001466a94afbed015.jpg
# 13_png.rf.06473ee33d1f28d374777c7bec00c122.jpg
# 13_png.rf.099adfa3fe11b3b63641e4e70bd5136f.jpg
# 13_png.rf.725eb52f0276360fd9abb308897690eb.jpg
# 14_png.rf.ae4a606367c45ac9185c2787a7dc1cb7.jpg
# 14_png.rf.da83e9f3a514a02acea543698056dfd9.jpg
# 14_png.rf.e68163e56fed8d86144e27e5832fae78.jpg
# 15_png.rf.158dbc6513701a5280e0a1c7d4c2850d.jpg
# 15_png.rf.1ab1c10d10a145e8352ba3d31d1ccdf6.jpg
# 15_png.rf.b0d789e99d1176d85b969ae558208a36.jpg
# 151_png.rf.ee8696416d510b2e48d520fdcc0ac74a.jpg
# 152_png.rf.0dc3388359353319da5e94b73246d87b.jpg
# 153_png.rf.6481127ab2d038d7cce33f1aca9bd5b1.jpg
# 154_png.rf.1dbdd7b07cdb82d6bbd6fa22554a3cc5.jpg
# ...

# %%
# !make clean
# !make
# Out:
# rm -rf ./obj/image_opencv.o ./obj/http_stream.o ./obj/gemm.o ./obj/utils.o ./obj/dark_cuda.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/darknet.o ./obj/detection_layer.o ./obj/captcha.o ./obj/route_layer.o ./obj/writing.o ./obj/box.o ./obj/nightmare.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/coco.o ./obj/dice.o ./obj/yolo.o ./obj/detector.o ./obj/layer.o ./obj/compare.o ./obj/classifier.o ./obj/local_layer.o ./obj/swag.o ./obj/shortcut_layer.o ./obj/representation_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/rnn.o ./obj/rnn_vid.o ./obj/crnn_layer.o ./obj/demo.o ./obj/tag.o ./obj/cifar.o ./obj/go.o ./obj/batchnorm_layer.o ./obj/art.o ./obj/region_layer.o ./o
# ...

# %%
# !chmod 755 ./darknet

# %%
download_from_official = True

if download_from_official:
  # !wget https://pjreddie.com/media/files/yolov3.weights
  # !wget https://pjreddie.com/media/files/darknet53.conv.74
  # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
  # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
else:
  # !cp /mydrive/<上次保存權重檔的地方>/yolov4_custom_last.weights ./backup
# Out:
# --2024-05-30 14:36:24--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  41.6MB/s    in 6.0s
#
# 2024-05-30 14:36:30 (39.2 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2024-05-30 14:36:30--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  37.6MB/s    in 4.5s
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def isShow(path):
  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image, (3*width, 3*height),interpolation=cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
isShow("predictions.jpg")

# %%
# !./darknet detector train data/obj.data cfg/yolov4-custom.cfg yolov4.conv.137 -dont_show
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.912769), count: 17, class_loss = 0.000172, iou_loss = 74.467773, total_loss = 74.467949
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.940046), count: 3, class_loss = 0.000005, iou_loss = 1.890860, total_loss = 1.890866
#  total_bbox = 11466029, rewritten_bbox = 0.033516 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.910285), count: 29, class_loss = 0.007698, iou_loss = 429.973663, total_loss = 429.981354
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.921105), count: 19, class_loss = 0.004432, iou_loss = 70.907166, total_loss = 70.911598
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.914439), count: 8, class_loss = 0.000046, iou_loss = 3.295692, total_loss = 3.295738
#  total_bbox = 11466085, rewritten_bbox = 0.033516 %
# ...

# %%
# !ls
# Out:
# 3rdparty		 DarknetConfig.cmake.in  include		scripts
# backup			 darknet_images.py	 json_mjpeg_streams.sh	src
# build			 darknet.py		 LICENSE		vcpkg.json
# build.ps1		 darknet_video.py	 Makefile		vcpkg.json.opencv23
# cfg			 data			 net_cam_v3.sh		video_yolov3.sh
# chart.png		 docker-compose.yml	 net_cam_v4.sh		video_yolov4.sh
# chart_yolov4-custom.png  Dockerfile.cpu		 obj			yolov3.weights
# cmake			 Dockerfile.gpu		 package.xml		yolov4.conv.137
# CMakeLists.txt		 generate_train.py	 predictions.jpg	yolov4.weights
# darknet			 image_yolov3.sh	 README.md
# darknet53.conv.74	 image_yolov4.sh	 results

# %%
# !cp ./backup/yolov4-custom_last.weights ../yolov4-custom_last.weights

# %%
# !./darknet detector train data/obj.data cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights -dont_show
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.795252), count: 35, class_loss = 9.622048, iou_loss = 421.266968, total_loss = 430.889008
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.815783), count: 30, class_loss = 3.349218, iou_loss = 117.893562, total_loss = 121.242783
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.265802), count: 3, class_loss = 0.157765, iou_loss = 0.179186, total_loss = 0.336950
#  total_bbox = 564811, rewritten_bbox = 0.026026 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.791877), count: 24, class_loss = 2.829647, iou_loss = 313.566071, total_loss = 316.395721
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.806550), count: 39, class_loss = 4.223918, iou_loss = 175.251846, total_loss = 179.475769
# ...

# %%
# !ls
# Out:
# 3rdparty		 DarknetConfig.cmake.in  image_yolov4.sh	results
# backup			 darknet_images.py	 include		scripts
# build			 darknet.py		 json_mjpeg_streams.sh	src
# build.ps1		 darknet_video.py	 LICENSE		vcpkg.json
# cfg			 data			 Makefile		vcpkg.json.opencv23
# chart.png		 demo2.mp4		 net_cam_v3.sh		video_yolov3.sh
# chart_yolov4-custom.png  docker-compose.yml	 net_cam_v4.sh		video_yolov4.sh
# cmake			 Dockerfile.cpu		 obj			yolov3.weights
# CMakeLists.txt		 Dockerfile.gpu		 package.xml		yolov4.conv.137
# darknet			 generate_train.py	 predictions.jpg	yolov4.weights
# darknet53.conv.74	 image_yolov3.sh	 README.md

# %%
# !cp /mydrive/project2_2023/demo2.mp4 ./

# %%
# !./darknet detector demo data/obj.data cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights -dont_show PTSD.mp4 -out_filename PTSD_out.mp4 -ext_output
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# car: 99% 	(left_x: 1159   top_y:  197   width:   52   height:   64)
# car: 99% 	(left_x: 1194   top_y:   82   width:   25   height:   28)
# car: 98% 	(left_x: 1048   top_y:  105   width:   27   height:   37)
#
# FPS:27.7 	 AVG_FPS:20.1
#
#  cvWriteFrame
# Objects:
#
# truck: 99% 	(left_x: 1231   top_y:  144   width:   91   height:  113)
# truck: 98% 	(left_x:  907   top_y:  111   width:   87   height:   83)
# truck: 97% 	(left_x:  332   top_y:  238   width:  271   height:  333)
# truck: 96% 	(left_x:  953   top_y:   86   width:   71   height:   61)
# car: 100% 	(left_x:  800   top_y:  316   width:  100   height:   80)
# car: 100% 	(left_x:  449   top_y:  571   width:  202   height:  149)
# car: 100% 	(left_x:  921   top_y:  232   width:   58   height:   47)
# car: 100% 	(left_x: 1004   top_y:  158   width:   31   height:   31)
# car: 100% 	(left_x: 1018   top_y:  128   width:   37   height:   34)
# ...

# %%
# !cp ./demo2_out.mp4 /mydrive/project2_class2/

# %%
# !./darknet detector map data/obj.data cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
# ...
